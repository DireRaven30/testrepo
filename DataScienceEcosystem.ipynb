# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, we are going to quickly summarise Data Science Tools and Ecosystem.

# %% [markdown]
# **Objectives:**
# - List some popular languages for data science
# - List some commonly used libraries for data science
# - Give some examples of commonly used data science tools
# - Give some examples of arithmetic expressions evaluated in Python

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. NumPy
# 3. Matplotlib
# 4. Scikit-learn

# %% [markdown]
# | Data Science Tools |
# | ------------------- |
# | Jupyter Notebooks |
# |       RStudio       |
# | IBM Watson Studio |

# %% [markdown]
# ### Below are a few examples of evaluating artithmetic expressions in Python

# %%
# This is an expression to multiply and then add integers.
(3*4)+5
# Out:
# 17

# %%
# This is an expression to convert 200 minutes into hours by dividing by 60.
200 / 60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Katharine Piper
